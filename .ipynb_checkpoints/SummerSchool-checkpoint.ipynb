# %% [markdown]
# # Zemanta Data Science Summer School 2018
# ## Data Science Basics

# %%
import re
import scipy as sp
import numpy as np
import pandas as pd
import graphviz
from sklearn import tree
# %matplotlib inline
from sklearn import linear_model
import matplotlib.pyplot as plt

# %% [markdown]
# In the cell below you can add more functions
# <br> Keeping the code seperate like this will help you keep you code clean and readable

# %%
def remove_outliers(data, col):
    m = data[col].mean()
    s = data[col].std()
    return data[(data[col] < m + 2*s) & (data[col] >  m - 2*s)]

# %% [markdown]
# The data can be downloaded at https://www.kaggle.com/fernandol/countries-of-the-world
# <br>unzip it and place it in this folder
# <br>The cell below is used to make a new csv file, that can be read properly using pandas

# %%
with open('countries of the world.csv', 'r') as f:
    out = re.sub(r'"[0-9]+,[0-9]+"', lambda x: x.group(0).replace(",", "."), f.read())
    with open('countries.csv', 'w') as f2:
        f2.write(out)

# %% [markdown]
# ### Data import and cleaning

# %%
df = pd.read_csv('countries.csv',
                 usecols=['Country', 'Region', 'Population',
                          'Area (sq. mi.)', 'GDP ($ per capita)',
                          'Birthrate', 'Deathrate'],
                 dtype={'Country': 'category', 'Region': 'category',
                        'Population': np.float64, 'Area (sq. mi.)': np.float32,
                        'GDP ($ per capita)': np.float32, 'Birthrate': np.float32,
                        'Deathrate': np.float32})
df.columns = ['country', 'region', 'population', 'area', 'gdp', 'birthrate', 'deathrate']
df.country = df.country.str.strip()
df.region = df.region.str.strip()

# %%
df.isnull().sum()
# Out:
# country       0
# region        0
# population    0
# area          0
# gdp           1
# birthrate     3
# deathrate     4
# dtype: int64

# %%
len(df.dropna()) / len(df)
# Out:
# 0

# %% [markdown]
# Removes all rows that are missing values, not the best practice in general, but above we checked, how many lines are missing data and decided, that this would be a good solution

# %%
df.dropna(inplace=True)

# %% [markdown]
# We can always add more columns to the existing DataFrame

# %%
df['coefficient'] = df.birthrate / df.deathrate
df['area_per_person'] = df.area / df.population

# %%
df[df.coefficient < 1]
# Out:
#             country               region   population        area      gdp  \
# 12          Austria       WESTERN EUROPE    8192880.0     83870.0  30000.0
# 18          Belarus  C.W. OF IND. STATES   10293011.0    207600.0   6100.0
# 26         Botswana   SUB-SAHARAN AFRICA    1639833.0    600370.0   9000.0
# 30         Bulgaria       EASTERN EUROPE    7385367.0    110910.0   7600.0
# 50          Croatia       EASTERN EUROPE    4494749.0     56542.0  10600.0
# 53   Czech Republic       EASTERN EUROPE   10235455.0     78866.0  15700.0
# 64          Estonia              BALTICS    1324333.0     45226.0  12300.0
# 76          Germany       WESTERN EUROPE   82422299.0    357021.0  27600.0
# 79           Greece       WESTERN EUROPE   10688058.0    131940.0  20000.0
# 85         Guernsey       WESTERN EUROPE      65409.0        78.0  20000.0
# 92          Hungary       EASTERN EUROPE    9981334.0     93030.0  13900.0
# 99      Isle of Man       WESTERN EUROPE      75441.0       572.0  21000.0
# 101           Italy       WESTERN EUROPE   58133509.0    301230.0  26700.0
# 114          Latvia              BALTICS    2274735.0     64589.0  10200.0
# 116         Lesotho   SUB-SAHARAN AFRICA    2022331.0     30355.0   3000.0
# 120       Lithuania              BALTICS    3585906.0     65200.0  11400.0
# 138          Monaco       WESTERN EUROPE      32543.0         2.0  27000.0
# 163          Poland       EASTERN EUROPE   38536869.0    312685.0  11100.0
# 168         Romania       EASTERN EUROPE   22303552.0    237500.0   7000.0
# 169          Russia  C.W. OF IND. STATES  142893540.0  17075200.0   8900.0
# 186        Slovenia       EASTERN EUROPE    2010347.0     20273.0  19000.0
# 189    South Africa   SUB-SAHARAN AFRICA   44187637.0   1219912.0  10700.0
# 194       Swaziland   SUB-SAHARAN AFRICA    1136334.0     17363.0   4900.0
# 195          Sweden       WESTERN EUROPE    9016596.0    449964.0  26800.0
# 211         Ukraine  C.W. OF IND. STATES   46710816.0    603700.0   5400.0
#
#      birthrate  deathrate  coefficient  area_per_person
# 12    8.740000   9.760000     0.895492         0.010237
# 18   11.160000  14.020000     0.796006         0.020169
# 26   23.080000  29.500000     0.782373         0.366117
# 30    9.650000  14.270000     0.676244         0.015018
# 50    9.610000  11.480000     0.837108         0.012580
# 53    9.020000  10.590000     0.851747         0.007705
# 64   10.040000  13.250000     0.757736         0.034150
# 76    8.250000  10.620000     0.776836         0.004332
# 79    9.680000  10.240000     0.945313         0.012345
# 85    8.810000  10.010000     0.880120         0.001192
# 92    9.720000  13.110000     0.741419         0.009320
# 99   11.050000  11.190000     0.987489         0.007582
# 101   8.720000  10.400000     0.838462         0.005182
# 114   9.240000  13.660000     0.676428         0.028394
# 116  24.750000  28.709999     0.862069         0.015010
# 120   8.750000  10.980000     0.796903         0.018182
# 138   9.190000  12.910000     0.711851         0.000061
# 163   9.850000   9.890000     0.995956         0.008114
# 168  10.700000  11.770000     0.909091         0.010649
# 169   9.950000  14.650000     0.679181         0.119496
# 186   8.980000  10.310000     0.870999         0.010084
# 189  18.200001  22.000000     0.827273         0.027608
# 194  27.410000  29.740000     0.921654         0.015280
# 195  10.270000  10.310000     0.996120         0.049904
# 211   8.820000  14.390000     0.612926         0.012924

# %%
df = remove_outliers(df, 'area_per_person')

# %% [markdown]
# ### Modeling and plotting

# %%
# x = df.loc[:, df.columns != 'gdp']
x = df.birthrate
y = df.gdp

# %%
x = x.values.reshape(-1, 1)
y = y.values.reshape(-1, 1)

# %%
regr = linear_model.LinearRegression()
regr.fit(x, y)

plt.scatter(x, y,  color='black')
plt.plot(x, regr.predict(x), color='orange', linewidth=3)
plt.ylabel('area per person')
plt.xlabel('GDP')
plt.show()

# %%
regr.score(x,y)
# Out:
# 0.4226510103820851

# %%
def getModelScore():
    df1 = df.loc[:,(df.columns != 'region') & (df.columns != 'country')& (df.columns != 'coefficient')]
    random = pd.DataFrame(np.random.randn(df1.shape[0], 2))
    msk = np.random.rand(len(random)) < 0.8

    train = df1[msk]
    test = df1[~msk]

    x = train.loc[:,train.columns != 'gdp']
    y = train.gdp

    xt = test.loc[:,test.columns != 'gdp']
    yt = test.gdp

    clf = tree.DecisionTreeRegressor(max_depth = 1)
    clf.fit(x, y)
    return clf.score(xt,yt)

# plt.scatter(xt, yt,  color='black')
# plt.plot(xt, clf.predict(xt), color='orange', linewidth=3)
# plt.ylabel('area per person')
# plt.xlabel('GDP')
# plt.show()

# %%
results = []
for i in range(100):
    results.append(getModelScore())
    
np.mean(results)
# Out:
# 0.49899638464723245

# %%
graphdata = tree.export_graphviz(clf, out_file=None);
graph = graphviz.Source(graphdata)

# %%
graph

# %%
x
# Out:
#       population       area  birthrate  deathrate  coefficient  \
# 2     32930091.0  2381740.0  17.139999   4.610000     3.718004
# 4        71201.0      468.0   8.710000   6.250000     1.393600
# 5     12127071.0  1246700.0  45.110001  24.200001     1.864050
# 6        13477.0      102.0  14.170000   5.340000     2.653558
# 7        69108.0      443.0  16.930000   5.370000     3.152700
# 8     39921833.0  2766890.0  16.730000   7.550000     2.215894
# 9      2976372.0    29800.0  12.070000   8.230000     1.466586
# 10       71891.0      193.0  11.030000   6.680000     1.651198
# 11    20264082.0  7686850.0  12.140000   7.510000     1.616511
# 12     8192880.0    83870.0   8.740000   9.760000     0.895492
# 13     7961619.0    86600.0  20.740000   9.750000     2.127179
# 14      303770.0    13940.0  17.570000   9.050000     1.941436
# 15      698585.0      665.0  17.799999   4.140000     4.299517
# 17      279912.0      431.0  12.710000   8.670000     1.465975
# 18    10293011.0   207600.0  11.160000  14.020000     0.796006
# 19    10379067.0    30528.0  10.380000  10.270000     1.010711
# 20      287730.0    22966.0  28.840000   5.720000     5.041958
# 21     7862944.0   112620.0  38.849998  12.220000     3.179214
# 23     2279723.0    47000.0  33.650002  12.700000     2.649606
# 25     4498976.0    51129.0   8.770000   8.270000     1.060459
# 26     1639833.0   600370.0  23.080000  29.500000     0.782373
# 27   188078227.0  8511965.0  16.559999   6.170000     2.683954
# 28       23098.0      153.0  14.890000   4.420000     3.368778
# 29      379444.0     5770.0  18.790001   3.450000     5.446377
# 31    13902972.0   274200.0  45.619999  15.600000     2.924359
# 32    47382633.0   678500.0  17.910000   9.830000     1.821974
# 33     8090068.0    27830.0  42.220001  13.460000     3.136701
# 34    13881427.0   181040.0  26.900000   9.060000     2.969095
# 35    17340702.0   475440.0  33.889999  13.470000     2.515961
# 36    33098932.0  9984670.0  10.780000   7.800000     1.382051
# ..           ...        ...        ...        ...          ...
# 190   40397842.0   504782.0  10.060000   9.720000     1.034979
# 192   41236378.0  2505810.0  34.529999   8.970000     3.849498
# 193     439117.0   163270.0  18.020000   7.270000     2.478680
# 194    1136334.0    17363.0  27.410000  29.740000     0.921654
# 195    9016596.0   449964.0  10.270000  10.310000     0.996120
# 196    7523934.0    41290.0   9.710000   8.490000     1.143698
# 197   18881361.0   185180.0  27.760000   4.810000     5.771310
# 198   23036087.0    35980.0  12.560000   6.480000     1.938272
# 200   37445392.0   945087.0  37.709999  16.389999     2.300793
# 201   64631595.0   514000.0  13.870000   7.040000     1.970170
# 202    5548702.0    56785.0  37.009998   9.830000     3.765005
# 203     114689.0      748.0  25.370001   5.280000     4.804924
# 204    1065842.0     5128.0  12.900000  10.570000     1.220435
# 205   10175014.0   163610.0  15.520000   5.130000     3.025341
# 206   70413958.0   780580.0  16.620001   5.970000     2.783920
# 207    5042920.0   488100.0  27.610001   8.600000     3.210465
# 208      21152.0      430.0  21.840000   4.210000     5.187648
# 209      11810.0       26.0  22.180000   7.110000     3.119550
# 210   28195754.0   236040.0  47.349998  12.240000     3.868464
# 211   46710816.0   603700.0   8.820000  14.390000     0.612926
# 212    2602713.0    82880.0  18.959999   4.400000     4.309091
# 213   60609153.0   244820.0  10.710000  10.130000     1.057256
# 214  298444215.0  9631420.0  14.140000   8.260000     1.711864
# 215    3431932.0   176220.0  13.910000   9.050000     1.537017
# 217     208869.0    12200.0  22.719999   7.820000     2.905371
# 219   84402966.0   329560.0  16.860001   6.220000     2.710611
# 220     108605.0     1910.0  13.960000   6.430000     2.171073
# 222    2460492.0     5860.0  31.670000   3.920000     8.079082
# 225   11502010.0   752614.0  41.000000  19.930000     2.057200
# 226   12236805.0   390580.0  28.010000  21.840000     1.282509
#
#      area_per_person
# 2           0.072327
# 4           0.006573
# 5           0.102803
# 6           0.007568
# 7           0.006410
# 8           0.069308
# 9           0.010012
# 10          0.002685
# 11          0.379334
# 12          0.010237
# 13          0.010877
# 14          0.045890
# 15          0.000952
# 17          0.001540
# 18          0.020169
# 19          0.002941
# 20          0.079818
# 21          0.014323
# 23          0.020617
# 25          0.011365
# 26          0.366117
# 27          0.045258
# 28          0.006624
# 29          0.015206
# 31          0.019722
# 32          0.014320
# 33          0.003440
# 34          0.013042
# 35          0.027418
# 36          0.301661
# ..               ...
# 190         0.012495
# 192         0.060767
# 193         0.371814
# 194         0.015280
# 195         0.049904
# 196         0.005488
# 197         0.009808
# 198         0.001562
# 200         0.025239
# 201         0.007953
# 202         0.010234
# 203         0.006522
# 204         0.004811
# 205         0.016080
# 206         0.011086
# 207         0.096789
# 208         0.020329
# 209         0.002202
# 210         0.008371
# 211         0.012924
# 212         0.031844
# 213         0.004039
# 214         0.032272
# 215         0.051347
# 217         0.058410
# 219         0.003905
# 220         0.017587
# 222         0.002382
# 225         0.065433
# 226         0.031918
#
# [184 rows x 6 columns]

# %%
df.groupby(['region'], as_index=False).population.mean()
# Out:
#                   region    population
# 0   ASIA (EX. NEAR EAST)  1.317137e+08
# 1                BALTICS  2.394991e+06
# 2    C.W. OF IND. STATES  2.334013e+07
# 3         EASTERN EUROPE  1.004712e+07
# 4    LATIN AMER. & CARIB  1.248499e+07
# 5              NEAR EAST  1.219177e+07
# 6        NORTHERN AFRICA  3.222682e+07
# 7       NORTHERN AMERICA  8.290399e+07
# 8                OCEANIA  1.741803e+06
# 9     SUB-SAHARAN AFRICA  1.469484e+07
# 10        WESTERN EUROPE  1.415500e+07

# %%
df.groupby(['region'], as_index=False).agg({'population': [np.sum, np.mean, np.std], 'gdp': [np.sum]})
# Out:
#                   region       gdp    population
#                                sum           sum          mean           std
# 0   ASIA (EX. NEAR EAST)  225500.0  3.687982e+09  1.317137e+08  3.102610e+08
# 1                BALTICS   33900.0  7.184974e+06  2.394991e+06  1.135572e+06
# 2    C.W. OF IND. STATES   48000.0  2.800815e+08  2.334013e+07  3.973450e+07
# 3         EASTERN EUROPE  115500.0  1.105183e+08  1.004712e+07  1.105527e+07
# 4    LATIN AMER. & CARIB  390700.0  5.618246e+08  1.248499e+07  3.235397e+07
# 5              NEAR EAST  167300.0  1.950684e+08  1.219177e+07  1.819645e+07
# 6        NORTHERN AFRICA   27300.0  1.611341e+08  3.222682e+07  2.897430e+07
# 7       NORTHERN AMERICA  110500.0  3.316159e+08  8.290399e+07  1.445363e+08
# 8                OCEANIA  164500.0  3.309425e+07  1.741803e+06  4.732649e+06
# 9     SUB-SAHARAN AFRICA  118500.0  7.494370e+08  1.469484e+07  2.309189e+07
# 10        WESTERN EUROPE  757300.0  3.963400e+08  1.415500e+07  2.315879e+07
